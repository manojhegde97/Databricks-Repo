# %%
import json
notebook_info = json.loads(dbutils.notebook.entry_point.getDbutils().notebook().getContext().toJson())
runid = notebook_info["tags"]["multitaskParentRunId"]
str="https://cust-e2-shubhamuc.cloud.databricks.com/?o=1441385103001642#job/343172569144676/run/"
runurl=str+runid
print(runurl)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">hi
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# ...

# %%
from databricks_dash import DatabricksDash
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Exception</span>                                 Traceback (most recent call last)
# ...

# %%
pip install databricks-dash
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.
# </div>

# %%
# %run /Users/manoj.hegde+uc@databricks.com/new1 $URL="runurl"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">url is runurl
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import requests

shard_url = "https://cust-e2-shubhamuc.cloud.databricks.com"
access_token = "dapibfc4aa184003080e1b709c6731838d42"

url = shard_url + "/api/2.0/clusters/list"

headers = {
 'Authorization': 'Bearer ' + access_token
}

cluster = requests.request("GET", url, headers=headers).json()

for group in cluster["clusters"]:
    if group.get('cluster_source')!="JOB":
        url2 = shard_url + "/api/2.0/clusters/pin"
        requests.post(url2,headers=headers,json={"cluster_id" : group["cluster_id"]})
        print("pinned cluster: "+group["cluster_id"]+" "+group["cluster_name"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">unpinned cluster: 0802-045300-6g4qk1pk manoj-test
# unpinned cluster: 0805-085210-lpsed2wm test-susumu-uctest
# unpinned cluster: 0706-085646-ntsek7av test
# unpinned cluster: 0902-040319-8kzyiazd 11.x test
# unpinned cluster: 0902-070311-4njb0rd9 Shubham Nautiyal&#39;s Cluster
# unpinned cluster: 0823-040114-1w4yats manoj 7.3
# unpinned cluster: 0816-013122-frl31iwf test-susumu-11
# unpinned cluster: 0817-091847-fe5zvv95 test-susumu-7.3
# unpinned cluster: 0808-014102-qdw55p06 test-susumu-9.1
# unpinned cluster: 0818-133348-ojt4lyir Susumu PostgresTest
# </div>

# %%
import requests

shard_url = "https://cust-e2-shubhamuc.cloud.databricks.com"
access_token = "dapibfc4aa184003080e1b709c6731838d42"
headers = {
 'Authorization': 'Bearer ' + access_token
}
url2 = shard_url + "/api/2.0/clusters/pin"
requests.post(url2,,json={"cluster_id" : "0808-014102-qdw55p06"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: &lt;Response [200]&gt;</div>

# %%
import requests

url = "https://cust-e2-shubhamuc.cloud.databricks.com/api/2.0/clusters/list"

payload={}
headers = {
  'Authorization': 'Bearer dapibfc4aa184003080e1b709c6731838d42'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.json)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;bound method Response.json of &lt;Response [200]&gt;&gt;
# </div>

# %%
for group in cluster["clusters"]:
    if not 'pinned_by_user_name' in group :
        print(group["default_tags"]['ClusterName'])
        url = shard_url + "/api/2.0/clusters/pin"
        requests.post(url,json={"cluster_id" : group["cluster_id"]})
    else:
        print(group["default_tags"]['ClusterName']+", "+group['pinned_by_user_name'])
